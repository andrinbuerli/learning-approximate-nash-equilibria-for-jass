# %%
from pathlib import Path
import pprint
import json
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=12)

# %%
means = np.array([0.50853, 0.50924, 0.51011, 0.51218, 0.51451])*100
stes = np.array([0.00281, 0.00275, 0.00275, 0.00277, 0.00271])*100
iterations = [20, 50, 100, 400, 800]

# %%
plt.figure(dpi=300)
plt.plot(iterations, means)
plt.fill_between(iterations, means-stes, means+stes, alpha=0.5)
plt.xscale('log')
plt.xticks(iterations)
plt.gca().get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
plt.xlabel("MCTS Iterations"), plt.ylabel("APA Local Policy")
# Out:
# (Text(0.5, 0, 'MCTS Iterations'), Text(0, 0.5, 'APA Local Policy'))

# %%
plt.figure(dpi=300) 
plt.bar(range(len(iterations)), means, yerr=stes, capsize=10)
#plt.fill_between(iterations, means-stes, means+stes, alpha=0.5)
plt.ylim([50, 52])
#plt.xticks(iterations)
plt.gca().set_xticklabels([0]+iterations) 
plt.xlabel("MCTS Iterations"), plt.ylabel("Points against Local Policy")
# Out:
# /tmp/ipykernel_165322/392355602.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels([0]+iterations)
# (Text(0.5, 0, 'MCTS Iterations'), Text(0, 0.5, 'Points against Local Policy'))
