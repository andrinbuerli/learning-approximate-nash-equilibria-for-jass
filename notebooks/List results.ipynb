# %%
from pathlib import Path
import pprint
import json
import numpy as np
from collections import defaultdict
import pandas as pd
from IPython.display import display, HTML
from ipywidgets import interact
from scipy.stats import t
from scipy.stats import ttest_ind, ttest_1samp

# %%
folders = list(sorted(Path(f"data/agents_eval_results/").glob("*"), reverse=False))
folders
# Out:
# [PosixPath('agents_eval_results/experiment-0'),
#  PosixPath('agents_eval_results/experiment-1'),
#  PosixPath('agents_eval_results/experiment-2'),
#  PosixPath('agents_eval_results/experiment-3'),
#  PosixPath('agents_eval_results/experiment-3-1'),
#  PosixPath('agents_eval_results/experiment-4'),
#  PosixPath('agents_eval_results/experiment-4-1'),
#  PosixPath('agents_eval_results/experiment-4-more-exploration'),
#  PosixPath('agents_eval_results/oos'),
#  PosixPath('agents_eval_results/oos-eval'),
#  PosixPath('agents_eval_results/tmp')]

# %% [markdown]
# # Experiment wise tables

# %%
@interact(folder=folders)
def f(folder):
    print(40*"-")
    print(folder, "(p1: mu<= 50%, p2: mu = 50%)")
    print(40*"-")
    relevant_data = defaultdict(lambda: {})
    files = folder.glob("tmp/*.json")

    for file in files:
        with open(str(file), "r") as f:
            data = json.load(f)
        
        name =  Path(file).name.replace(".json", "")
        opponent = name.split("-vs-")[0].replace("-", " ")
        agent = name.split("-vs-")[1].replace("-", " ")

        key = [x for x in data.keys() if not x.__contains__("DMCTS") and not x.__contains__("DPolicy")
               and not x.__contains__("random") and not x.__contains__("PMCTS") and not x.__contains__("mean")
               and not x.__contains__("Policy-B") and not x.__contains__("Policy-RAW") and not x.__contains__("MCTS-100-3")][0]

        relevant_data[agent][opponent] = data[key]
            
    data = {k: {x: np.array(y) for x, y in v.items()} for k,v in relevant_data.items()}
    data = {k: {x: y[:4*(y.shape[0]//4)].reshape(-1, 4) for x, y in v.items()} for k,v in data.items()}
    data = {k: {x: y 
                for x, y in sorted(v.items(), key=lambda item: item[0])}
            for k, v in sorted(data.items(), key=lambda item: item[0], reverse=True)} 
    
    print_data = {}
    
    for agent in data:
        print_data[agent] = {}
        for x, y in data[agent].items():
            mu =y.mean(axis=1).mean()
            ste = y.mean(axis=1).std() / np.sqrt(y.shape[0])
            p1 = ttest_1samp(y.reshape(-1), 0.5, nan_policy='omit', alternative='greater').pvalue
            p2 = ttest_1samp(y.reshape(-1), 0.5, nan_policy='omit', alternative='two-sided').pvalue
            
            print_data[agent][x] = f"{mu.round(5)}+-{ste.round(5)} {y.shape}, p1={p1.round(5)}, p2={p2.round(5)}"
    
    df = pd.DataFrame(print_data).T
    
    display(HTML(df.to_html()))
    
    print(40*"-")
    print("Compare distributions of row agents:")
    print(40*"-")
    
    @interact(agent1=df.index, agent2=df.index)
    def f(agent1, agent2):
        
        for opponent in df.columns:
            if opponent in data[agent1] and opponent in data[agent2]:
                length = min(data[agent1][opponent].reshape(-1).shape[0], data[agent2][opponent].reshape(-1).shape[0])
                print(opponent, length)
                print(ttest_ind(data[agent1][opponent].reshape(-1)[:length],
                                data[agent2][opponent].reshape(-1)[:length], nan_policy='omit'))
# Out:
# interactive(children=(Dropdown(description='folder', options=(PosixPath('agents_eval_results/experiment-0'), P…

# %% [markdown]
# # All data

# %%
print(40*"-")
print("null hypotheses is mu<= 50%")
print(40*"-")


all_data = {}

for folder in folders:
    relevant_data = defaultdict(lambda: {})
    files = folder.glob("tmp/*.json")

    for file in files:
        with open(str(file), "r") as f:
            data = json.load(f)
        
        name =  Path(file).name.replace(".json", "")
        opponent = name.split("-vs-")[0].replace("-", " ")
        agent = name.split("-vs-")[1].replace("-", " ")

        key = [x for x in data.keys() if not x.__contains__("DMCTS") and not x.__contains__("DPolicy")
               and not x.__contains__("random") and not x.__contains__("PMCTS") and not x.__contains__("mean")
               and not x.__contains__("Policy-B") and not x.__contains__("Policy-RAW") and not x.__contains__("MCTS-100-3")][0]

        relevant_data[f"{folder}/{agent}"][opponent] = data[key]
            
    data = {k: {x: np.array(y) for x, y in v.items()} for k,v in relevant_data.items()}
    data = {k: {x: y[:4*(y.shape[0]//4)].reshape(-1, 4) for x, y in v.items()} for k,v in data.items()}
    data = {k: {x: y 
                for x, y in sorted(v.items(), key=lambda item: item[0])}
            for k, v in sorted(data.items(), key=lambda item: item[0], reverse=True)} 
    
    all_data.update(**data)
    
 
    
print_data = {}   
for agent in all_data:
    print_data[agent] = {}
    for x, y in all_data[agent].items():
        mu =y.mean(axis=1).mean()
        ste = y.mean(axis=1).std() / np.sqrt(y.shape[0])
        p = ttest_1samp(y.reshape(-1), 0.5, nan_policy='omit', alternative='greater').pvalue

        print_data[agent][x] = f"{mu.round(5)}+-{ste.round(5)} {y.shape}, p={p.round(5)}"

df = pd.DataFrame(print_data).T

display(HTML(df.to_html()))

print(40*"-")
print("Compare distributions of row agents:")
print(40*"-")

@interact(agent1=df.index, agent2=df.index)
def f(agent1, agent2):

    for opponent in df.columns:
        if opponent in all_data[agent1] and opponent in all_data[agent2]:
            print(opponent)
            print(ttest_rel(all_data[agent1][opponent].reshape(-1)[:1000], 
                            all_data[agent2][opponent].reshape(-1)[:1000], nan_policy='omit'))
# Out:
# ----------------------------------------
# null hypotheses is mu<= 50%
# ----------------------------------------
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DMCTS</th>
#       <th>PMCTS</th>
#       <th>Policy B</th>
#       <th>F I DMCTS</th>
#       <th>I DMCTS</th>
#       <th>Policy RAW</th>
#       <th>MCTS 50</th>
#       <th>MCTS 100 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>agents_eval_results/experiment-0/Policy</th>
#       <td>0.51501+-0.00778 (250, 4), p=0.03279</td>
#       <td>0.43878+-0.00914 (250, 4), p=1.0</td>
#       <td>0.49568+-0.00791 (251, 4), p=0.69656</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-0/MCTS 100</th>
#       <td>0.55418+-0.00881 (250, 4), p=0.0</td>
#       <td>0.48306+-0.00964 (250, 4), p=0.96278</td>
#       <td>0.52394+-0.00909 (250, 4), p=0.00359</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-1/Policy</th>
#       <td>0.45245+-0.00752 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>0.43575+-0.00804 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-1/MCTS 100</th>
#       <td>0.45859+-0.00756 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>0.45157+-0.00743 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-2/Policy</th>
#       <td>0.40004+-0.00722 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>0.41148+-0.00684 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-2/MCTS 100</th>
#       <td>0.43087+-0.00697 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>0.42783+-0.00693 (250, 4), p=1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3/Policy</th>
#       <td>0.52427+-0.00254 (2500, 4), p=0.0</td>
#       <td>NaN</td>
#       <td>0.50308+-0.00264 (2501, 4), p=0.12033</td>
#       <td>0.50437+-0.00901 (250, 4), p=0.29869</td>
#       <td>0.48922+-0.00838 (250, 4), p=0.90965</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3/MCTS 50</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.49461+-0.00847 (250, 4), p=0.73154</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3/MCTS 400</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.48187+-0.00879 (250, 4), p=0.9837</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3/MCTS 20</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.51182+-0.00892 (250, 4), p=0.08359</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3/MCTS 100 3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.50543+-0.0237 (39, 4), p=0.40487</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3/MCTS 100</th>
#       <td>0.53179+-0.00254 (2502, 4), p=0.0</td>
#       <td>NaN</td>
#       <td>0.5113+-0.00261 (2501, 4), p=1e-05</td>
#       <td>0.51757+-0.00372 (1264, 4), p=0.0</td>
#       <td>0.50683+-0.00525 (707, 4), p=0.08885</td>
#       <td>0.5078+-0.00881 (250, 4), p=0.17665</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3-1/Policy</th>
#       <td>0.51873+-0.00816 (250, 4), p=0.0118</td>
#       <td>NaN</td>
#       <td>0.49984+-0.00882 (250, 4), p=0.50752</td>
#       <td>0.51546+-0.00802 (250, 4), p=0.02609</td>
#       <td>0.50366+-0.00836 (250, 4), p=0.33107</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-3-1/MCTS 100</th>
#       <td>0.53378+-0.0079 (250, 4), p=2e-05</td>
#       <td>NaN</td>
#       <td>0.50525+-0.00853 (250, 4), p=0.27056</td>
#       <td>0.5177+-0.00839 (250, 4), p=0.01691</td>
#       <td>0.51238+-0.0082 (250, 4), p=0.07091</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4/Policy</th>
#       <td>0.51728+-0.00261 (2500, 4), p=0.0</td>
#       <td>NaN</td>
#       <td>0.50284+-0.0027 (2500, 4), p=0.14444</td>
#       <td>0.52563+-0.00896 (250, 4), p=0.00119</td>
#       <td>0.47445+-0.00782 (250, 4), p=0.99908</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4/MCTS 800</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.51483+-0.0029 (2172, 4), p=0.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4/MCTS 50</th>
#       <td>0.53831+-0.00807 (250, 4), p=0.0</td>
#       <td>NaN</td>
#       <td>0.51649+-0.00932 (250, 4), p=0.02459</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.50924+-0.00275 (2500, 4), p=0.00037</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4/MCTS 400</th>
#       <td>0.53283+-0.00898 (250, 4), p=4e-05</td>
#       <td>NaN</td>
#       <td>0.49372+-0.00872 (250, 4), p=0.77313</td>
#       <td>NaN</td>
#       <td>0.49974+-0.00841 (250, 4), p=0.5121</td>
#       <td>0.50597+-0.00276 (2500, 4), p=0.01532</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4/MCTS 20</th>
#       <td>0.52836+-0.00824 (250, 4), p=0.00037</td>
#       <td>NaN</td>
#       <td>0.49778+-0.00871 (250, 4), p=0.60286</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.50853+-0.00281 (2500, 4), p=0.00097</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4/MCTS 100 Opp</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.49017+-0.02714 (40, 4), p=0.66797</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4/MCTS 100</th>
#       <td>0.53048+-0.00259 (2500, 4), p=0.0</td>
#       <td>NaN</td>
#       <td>0.51094+-0.00273 (2500, 4), p=3e-05</td>
#       <td>0.47442+-0.04615 (15, 4), p=0.76168</td>
#       <td>0.52753+-0.05299 (14, 4), p=0.22171</td>
#       <td>0.51011+-0.00275 (2500, 4), p=0.00013</td>
#       <td>NaN</td>
#       <td>0.50835+-0.00194 (5002, 4), p=1e-05</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4-1/Policy</th>
#       <td>0.52166+-0.00836 (250, 4), p=0.00377</td>
#       <td>NaN</td>
#       <td>0.51652+-0.00795 (250, 4), p=0.02872</td>
#       <td>0.50927+-0.00883 (250, 4), p=0.13113</td>
#       <td>0.49849+-0.00886 (250, 4), p=0.56962</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4-1/MCTS 800</th>
#       <td>0.52646+-0.00877 (250, 4), p=0.00065</td>
#       <td>NaN</td>
#       <td>0.50728+-0.00897 (250, 4), p=0.20066</td>
#       <td>NaN</td>
#       <td>0.50343+-0.00796 (250, 4), p=0.33882</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4-1/MCTS 50</th>
#       <td>0.52087+-0.00851 (250, 4), p=0.00624</td>
#       <td>NaN</td>
#       <td>0.4999+-0.0089 (250, 4), p=0.50479</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>agents_eval_results/experiment-4-1/MCTS 400</th>
#       <td>0.52239+-0.00819 (250, 4), p=0.00346
# ----------------------------------------
# Compare distributions of row agents:
# ----------------------------------------
# interactive(children=(Dropdown(description='agent1', options=('agents_eval_results/experiment-0/Policy', 'agen…
